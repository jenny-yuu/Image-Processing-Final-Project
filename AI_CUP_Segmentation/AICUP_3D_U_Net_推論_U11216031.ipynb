# %% [markdown]
# # 環境設定

# %%
import sys
# !{sys.executable} --version
# !{sys.executable} -m pip install -U numpy==1.26.4
import os
os._exit(0)
# Out:
# Python 3.11.13
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.4 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 137.1 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4

# %%
import sys
# !{sys.executable} -m pip install -U ray==2.5.0
import ray
print(ray.__version__)
# Out:
# Collecting ray==2.5.0
#   Downloading ray-2.5.0-cp311-cp311-manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.11/dist-packages (from ray==2.5.0) (25.3.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from ray==2.5.0) (8.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from ray==2.5.0) (3.18.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/dist-packages (from ray==2.5.0) (4.24.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ray==2.5.0) (1.1.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from ray==2.5.0) (24.2)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.11/dist-packages (from ray==2.5.0) (5.29.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from ray==2.5.0) (6.0.2)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.11/dist-packages (from ray==2.5.0) (1.4.0)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.11/dist-packages (from ray==2.5.0) (1.7.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from ray==2.5.0) (2.32.3)
# Collecting grpcio<=1.51.3,>=1.42.0 (from ray==2.5.0)
#   Downloading grpcio-1.51.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.11/dist-packages (from ray==2.5.0) (1.26.4)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.11/dist-packages (from aiosignal->ray==2.5.0) (4.14.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray==2.5.0) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray==2.5.0) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray==2.5.0) (0.26.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->ray==2.5.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->ray==2.5.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->ray==2.5.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->ray==2.5.0) (2025.7.14)
# Downloading ray-2.5.0-cp311-cp311-manylinux2014_x86_64.whl (56.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 MB 24.3 MB/s eta 0:00:00
# Downloading grpcio-1.51.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 162.9 MB/s eta 0:00:00
# Installing collected packages: grpcio, ray
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.73.1
#     Uninstalling grpcio-1.73.1:
#       Successfully uninstalled grpcio-1.73.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpcio-status 1.71.2 requires grpcio>=1.71.2, but you have grpcio 1.51.3 which is incompatible.
# Successfully installed grpcio-1.51.3 ray-2.5.0
# 2.5.0

# %%
import sys
# !{sys.executable} -m pip install -U monai==1.2.0
import monai
print(monai.__version__)
# Out:
# Collecting monai==1.2.0
#   Downloading monai-1.2.0-202306081546-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: torch>=1.9 in /usr/local/lib/python3.11/dist-packages (from monai==1.2.0) (2.6.0+cu124)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.11/dist-packages (from monai==1.2.0) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->monai==1.2.0) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->monai==1.2.0) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->monai==1.2.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->monai==1.2.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->monai==1.2.0) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.9->monai==1.2.0)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.9->monai==1.2.0)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.9->monai==1.2.0)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.9->monai==1.2.0)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.9->monai==1.2.0)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.9->monai==1.2.0)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.9->monai==1.2.0)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.9->monai==1.2.0)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.9->monai==1.2.0)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->monai==1.2.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->monai==1.2.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->monai==1.2.0) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.9->monai==1.2.0)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->monai==1.2.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.9->monai==1.2.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.9->monai==1.2.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.9->monai==1.2.0) (3.0.2)
# Downloading monai-1.2.0-202306081546-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 18.5 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 37.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 132.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 83.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 10.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 56.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 15.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.6 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 141.0 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, monai
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed monai-1.2.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# 1.2.0

# %%
# !{sys.executable} -m pip install -U ml_collections
# Out:
# Collecting ml_collections
#   Downloading ml_collections-1.1.0-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from ml_collections) (1.4.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from ml_collections) (6.0.2)
# Downloading ml_collections-1.1.0-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 3.6 MB/s eta 0:00:00
# Installing collected packages: ml_collections
# Successfully installed ml_collections-1.1.0

# %%
# !git clone https://github.com/kairaun/Sam.git
# Out:
# Cloning into 'Sam'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# %cd ./Sam
! ls
! head pyproject.toml
# !pip install -e .
import os
os._exit(0)
# Out:
# /content/Sam
# pyproject.toml
# [build-system]
# requires = [
#     "setuptools>=62.3.0,<75.9",
#     "torch>=2.5.1",
#     ]
# build-backend = "setuptools.build_meta"
# Obtaining file:///content/Sam
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Building wheels for collected packages: UNKNOWN
#   Building editable for UNKNOWN (pyproject.toml) ... done
#   Created wheel for UNKNOWN: filename=unknown-0.0.0-0.editable-py3-none-any.whl size=2557 sha256=5a1aaa85d096438f4703c0110f936e3cfad0fdb614b2147a4addc904567b4ac1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3y_lu3qb/wheels/4d/dd/8b/46a6ee24a860a2484f39a9b119ad19ebd742e574a063e7b881
# Successfully built UNKNOWN
# Installing collected packages: UNKNOWN
# Successfully installed UNKNOWN-0.0.0

# %%
import sys
# !{sys.executable} -m pip install -U --no-deps monailabel
import monailabel
print(monailabel.__version__)
# Out:
# Collecting monailabel
#   Downloading monailabel-0.8.5-202411252313-py3-none-any.whl.metadata (23 kB)
# Downloading monailabel-0.8.5-202411252313-py3-none-any.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 91.8 MB/s eta 0:00:00
# Installing collected packages: monailabel
# Successfully installed monailabel-0.8.5
# 0.8.5

# %%
# Clone the project
# !git clone https://github.com/kairaun/CardiacSegV2.git
# Out:
# Cloning into 'CardiacSegV2'...
# remote: Enumerating objects: 641, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 641 (delta 24), reused 8 (delta 8), pack-reused 610 (from 2)
# Receiving objects: 100% (641/641), 17.33 MiB | 35.13 MiB/s, done.
# Resolving deltas: 100% (180/180), done.

# %%
# Install the Environment
! sudo chmod 700 /content/CardiacSegV2/setup.sh
! /content/CardiacSegV2/setup.sh
! pip install gdown==4.6.0
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:8 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [83.2 kB]
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,123 kB]
# Get:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:13 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,825 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [69.2 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,594 kB]
# Get:16 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,434 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,856 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,168 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [83.9 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [35.2 kB]
# Get:21 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [5,969 kB]
# Get:22 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [38.5 kB]
# Get:23 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy/main amd64 Packages [44.9 kB]
# Get:24 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [60.9 kB]
# Get:25 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,526 kB]
# Get:26 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,289 kB]
# Fetched 37.6 MB in 3s (13.0 MB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 180 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libsm6 is already the newest version (2:1.2.3-1build2).
# libxext6 is already the newest version (2:1.3.4-1build1).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 180 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu113
# ERROR: Could not find a version that satisfies the requirement torch==1.12.1+cu113 (from versions: 1.13.0, 1.13.1, 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2, 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0, 2.7.0, 2.7.1, 2.8.0, 2.9.0)
# ERROR: No matching distribution found for torch==1.12.1+cu113
# Collecting gdown==4.6.0
#   Downloading gdown-4.6.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown==4.6.0) (3.18.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown==4.6.0) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from gdown==4.6.0) (1.17.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gdown==4.6.0) (4.67.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown==4.6.0) (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown==4.6.0) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown==4.6.0) (4.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown==4.6.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown==4.6.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown==4.6.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown==4.6.0) (2025.7.14)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown==4.6.0) (1.7.1)
# Downloading gdown-4.6.0-py3-none-any.whl (14 kB)
# Installing collected packages: gdown
#   Attempting uninstall: gdown
#     Found existing installation: gdown 5.2.0
#     Uninstalling gdown-5.2.0:
#       Successfully uninstalled gdown-5.2.0
# Successfully installed gdown-4.6.0

# %%
# Modify the code
! sed -i '8c \\    os.makedirs(\"/content/CardiacSegV2/\"+data_dir, exist_ok=True)' /content/CardiacSegV2/setup_dir.py
! sed -i '20c \\        os.makedirs(\"/content/CardiacSegV2/\"+model_exp_dir, exist_ok=True)' /content/CardiacSegV2/setup_dir.py
! sed -i '29c \\        os.makedirs("/content/CardiacSegV2/"+model_exp_dir, exist_ok=True)' /content/CardiacSegV2/setup_dir.py
! sed -i '3c sys.path.append(\"/content/CardiacSegV2\")' /content/CardiacSegV2/expers/infer.py
! sed -i '3c sys.path.append(\"/content/CardiacSegV2\")' /content/CardiacSegV2/expers/tune.py
! sed -i '36c ray.init(runtime_env={\"working_dir\": \"/content/CardiacSegV2\"})' /content/CardiacSegV2/expers/tune.py

# %%
! python /content/CardiacSegV2/setup_dir.py
# Out:
# mkdir data: dataset/chgh
# mkdir exp: exps/exps/unet3d/chgh/tune_results

# %%
# !ls
# Out:
# CardiacSegV2  Sam  sample_data

# %%
# !pip install "pydantic<2.0"
# Out:
# Collecting pydantic<2.0
#   Downloading pydantic-1.10.24-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.0) (4.14.1)
# Downloading pydantic-1.10.24-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 55.8 MB/s eta 0:00:00
# Installing collected packages: pydantic
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.11.7
#     Uninstalling pydantic-2.11.7:
#       Successfully uninstalled pydantic-2.11.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# monailabel 0.8.5 requires bcrypt>=4.1.2, which is not installed.
# monailabel 0.8.5 requires dicomweb-client[gcp]>=0.59.1, which is not installed.
# monailabel 0.8.5 requires expiring_dict>=1.1.0, which is not installed.
# monailabel 0.8.5 requires expiringdict>=1.2.2, which is not installed.
# monailabel 0.8.5 requires girder-client>=3.2.3, which is not installed.
# monailabel 0.8.5 requires ninja>=1.11.1.1, which is not installed.
# monailabel 0.8.5 requires numpymaxflow>=0.0.7, which is not installed.
# monailabel 0.8.5 requires passlib>=1.7.4, which is not installed.
# monailabel 0.8.5 requires pydantic-settings>=2.2.1, which is not installed.
# monailabel 0.8.5 requires pydicom>=2.4.4, which is not installed.
# monailabel 0.8.5 requires pydicom-seg>=0.4.1, which is not installed.
# monailabel 0.8.5 requires pynetdicom>=2.0.2, which is not installed.
# monailabel 0.8.5 requires pynrrd>=1.0.0, which is not installed.
# monailabel 0.8.5 requires python-dotenv>=1.0.1, which is not installed.
# monailabel 0.8.5 requires sam2>=0.4.1; python_version >= "3.10", which is not installed.
# monailabel 0.8.5 requires schedule>=1.2.1, which is not installed.
# monailabel 0.8.5 requires timeloop>=1.0.2, which is not installed.
# monailabel 0.8.5 requires watchdog>=4.0.0, which is not installed.
# monailabel 0.8.5 requires monai[fire,gdown,ignite,itk,lmdb,mlflow,nibabel,openslide,pillow,psutil,skimage,tensorboard,torchvision,tqdm]>=1.4.0, but you have monai 1.2.0 which is incompatible.
# monailabel 0.8.5 requires pydantic>=2.7.0, but you have pydantic 1.10.24 which is incompatible.
# albumentations 2.0.8 requires pydantic>=2.9.2, but you have pydantic 1.10.24 which is incompatible.
# google-genai 1.25.0 requires pydantic<3.0.0,>=2.0.0, but you have pydantic 1.10.24 which is incompatible.
# gradio 5.31.0 requires pydantic<2.12,>=2.0, but you have pydantic 1.10.24 which is incompatible.
# langchain 0.3.26 requires pydantic<3.0.0,>=2.7.4, but you have pydantic 1.10.24 which is incompatible.
# langchain-core 0.3.68 requires pydantic>=2.7.4, but you have pydantic 1.10.24 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# thinc 8.3.6 requires pydantic<3.0.0,>=2.0.0, but you have pydantic 1.10.24 which is incompatible.
# Successfully installed pydantic-1.10.24

# %% [markdown]
# #執行推論 (儲存於Google Drive上)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
# create folder in drive
os.makedirs('/content/drive/MyDrive/myo_pred/chgh/image', exist_ok=True)
os.makedirs('/content/drive/MyDrive/myo_pred/chgh/infer', exist_ok=True)

# %%
import sys
workspace_dir = './content/CardiacSegV2'
sys.path.append(workspace_dir)
import os
import importlib
from pathlib import PurePath

import pandas as pd
from ray import tune
from ray.train.trainer import BaseTrainer

#from datasets.chgh_dataset import get_data_dicts
#from data_utils.utils import get_pids_by_data_dicts


def get_tune_model_dir(root_exp_dir, exp_name):
    experiment_path = os.path.join(root_exp_dir, exp_name)

    print(f"Loading results from {experiment_path}...")

    # restored_tuner = tune.Tuner.restore(
    #     experiment_path, trainable=BaseTrainer, resume_errored=True)
    # 727 fix
    restored_tuner = tune.Tuner.restore(experiment_path, trainable='main')
    result_grid = restored_tuner.get_results()

    best_result = result_grid.get_best_result(metric="tt_dice", mode="max")
    print(f"\nBest trial {best_result.metrics['trial_id']}: ")
    print('config:', best_result.config)
    print('tt_dice:', best_result.metrics['tt_dice'])
    # print('tt_iou:', best_result.metrics['tt_iou'])
    if 'esc' in best_result.metrics:
        print('esc:', best_result.metrics['esc'])
    print(f'best log dir:', best_result.log_dir)
    model_dir = os.path.join(best_result.log_dir, 'models')
    return model_dir


def get_tune_dir(exp_dir):
    restored_tuner = tune.Tuner.restore(exp_dir)
    result_grid = restored_tuner.get_results()
    best_result = result_grid.get_best_result(metric="tt_dice", mode="max")
    return best_result.log_dir


def get_data_path(data_dir, data_name, pid):
    dataset = importlib.import_module(f'datasets.{data_name}_dataset')
    _get_data_dicts = getattr(dataset, 'get_data_dicts', None)
    data_dicts = _get_data_dicts(data_dir)
    pids = get_pids_by_data_dicts(data_dicts)
    idx = pids.index(pid)
    return data_dicts[idx]


def get_pred_path(root_dir, exp_name, img_pth):
    return os.path.join(
        root_dir,
        'infers',
        exp_name,
        PurePath(img_pth).parts[-1]
    )


def get_eval_csv_path(root_dir):
    return os.path.join(
        root_dir,
        'evals',
        'best_model.csv'
    )


def get_eda_eval_csv_path(root_dir):
    return os.path.join(
        root_dir,
        'eda_evals',
        'best_model.csv'
    )


def get_eval_val(csv_pth, pid):
    df = pd.read_csv(csv_pth)
    idx = df['patientId'] == pid
    if 'inf_diceLV' in df[idx]:
        return {
            'dice': df[idx].filter(regex=("inf_dice*")).T.mean().tolist()[0],
            'iou': df[idx].filter(regex=("inf_iou*")).T.mean().tolist()[0]
        }
    else:
        return {
            'dice': df[idx]['inf_diceC'].tolist()[0],
            'iou': df[idx]['inf_iouC'].tolist()[0]
        }


def get_slice(img, slice_idx, mode, is_trans):
    '''
    mode: a, c, s
    '''
    if mode == 'a':
        img = img[:, :, slice_idx]
    elif mode == 's':
        img = img[:, slice_idx, :]
    else:
        img = img[slice_idx, :, :]

    if is_trans:
        return img.T
    else:
        return img


def get_img_lbl_preds(data, exp_names, slice_idxs, mode='a', is_trans=False):
    '''
    mode: a, c, s
    '''
    preds = []
    imgs = []
    lbls = []
    for slice_idx in slice_idxs:
        pred_ls = []
        for exp_name in exp_names:
            pred_ls.append(
                get_slice(data[exp_name], slice_idx, mode, is_trans))
        preds.append(pred_ls)
        imgs.append(get_slice(data['image'], slice_idx, mode, is_trans))
        lbls.append(get_slice(data['label'], slice_idx, mode, is_trans))
    return imgs, lbls, preds

# %% [markdown]
# # 確定Google Drive內容

# %%
import os
pred_img = []
for root, dirs, files in os.walk("/content/drive/MyDrive/myo_pred/chgh/image", topdown=False):
  for name in files:
    pred_img.append(os.path.join(root, name))
    print(os.path.join(root, name))
# Out:
# /content/drive/MyDrive/myo_pred/chgh/image/patient0051.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0052.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0053.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0054.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0055.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0056.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0058.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0057.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0059.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0060.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0061.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0062.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0063.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0065.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0064.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0066.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0068.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0067.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0069.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0070.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0071.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0073.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0072.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0074.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0075.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0077.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0076.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0078.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0079.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0080.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0081.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0082.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0083.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0084.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0085.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0086.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0087.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0089.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0088.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0090.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0092.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0091.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0093.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0095.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0094.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0096.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0097.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0098.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0099.nii.gz
# /content/drive/MyDrive/myo_pred/chgh/image/patient0100.nii.gz

# %% [markdown]
# # 把預訓練檔從google drive上傳到colab內

# %%
import gdown
os.makedirs('/content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training', exist_ok=True)

#請在[位置id]處放上你的權重檔位置
# https://drive.google.com/file/d/[位置id]/view?usp=sharing
gdown.download("https://drive.google.com/u/0/uc?id=1nuIP890twkDsV3UlXU8XOWs7kwQrs32b&export=download","/content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training.zip")

! unzip "/content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training.zip" -d "/content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/"
# Out:
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1nuIP890twkDsV3UlXU8XOWs7kwQrs32b&export=download
# To: /content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training.zip
# 100%|██████████| 226M/226M [00:02<00:00, 76.9MB/s]
# Archive:  /content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training.zip
#    creating: /content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_0e73f_00000_0_exp=exp_AICUP_training_2025-11-03_07-31-05/
#   inflating: /content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_0e73f_00000_0_exp=exp_AICUP_training_2025-11-03_07-31-05/params.pkl
#    creating: /content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_0e73f_00000_0_exp=exp_AICUP_training_2025-11-03_07-31-05/evals/
#   inflating: /content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_0e73f_00000_0_exp=exp_AICUP_training_2025-11-03_07-31-05/evals/best_model.csv
#    creating: /content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_0e73f_00000_0_exp=exp_AICUP_training_2025-11-03_07-31-05/models/
#   inflating: /content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_0e73f_00000_0_exp=exp_AICUP_training_2025-11-03_07-31-05/models/best_model.pth
#   inflating: /content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_0e73f_00000_0_exp=exp_AICUP_training_2025-11-03_07-31-05/models/final_model.pth
#   inflating: /content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_0e73f_00000_0_exp=exp_AICUP_training_2025-11-03_07-31-05/params.json
#   inflating: /content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_0e73f_00000_0_exp=exp_AICUP_training_2025-11-03_07-31-05/result.json
#   inflating: /content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_0e73f_00000_0_exp=exp_AICUP_training_2025-11-03_07-31-05/progress.csv
#    creating: /content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_0e73f_00000_0_exp=exp_AICUP_training_2025-11-03_07-31-05/logs/
#   inflating: /content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_0e73f_00000_0_exp=exp_AICUP_training_2025-11-03_07-31-05/logs/events.out.tfevents.1762155080.1c189092e5aa.8125.0
#   inflating: /content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_0e73f_00000_0_exp=exp_AICUP_training_2025-11-03_07-31-05/logs/events.out.tfevents.1762158918.1c189092e5aa.8125.1
#   inflating: /content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/tuner.pkl
#   inflating: /content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/basic-variant-state-2025-11-03_07-31-05.json
#   inflating: /content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/experiment_state-2025-11-03_07-31-05.json
#   inflating: /content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/basic-variant-state-2025-11-10_08-19-13.json
#   inflating: /content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/experiment_state-2025-11-10_08-19-13.json
#    creating: /content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_f1259_00000_0_exp=exp_AICUP_training_2025-11-10_08-19-13/
#   inflating: /content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_f1259_00000_0_exp=exp_AICUP_training_2025-11-10_08-19-13/params.pkl
#    creating: /content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_f1259_00000_0_exp=exp_AICUP_training_2025-11-10_08-19-13/evals/
#    creating: /content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_f1259_00000_0_exp=exp_AICUP_training_2025-11-10_08-19-13/models/
#   inflating: /content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_f1259_00000_0_exp=exp_AICUP_training_2025-11-10_08-19-13/models/best_model.pth
#   inflating: /content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_f1259_00000_0_exp=exp_AICUP_training_2025-11-10_08-19-13/models/final_model.pth
#   inflating: /content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_f1259_00000_0_exp=exp_AICUP_training_2025-11-10_08-19-13/params.json
#   inflating: /content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_f1259_00000_0_exp=exp_AICUP_training_2025-11-10_08-19-13/result.json
#   inflating: /content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_f1259_00000_0_exp=exp_AICUP_training_2025-11-10_08-19-13/progress.csv
#    creating: /content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_f1259_00000_0_exp=exp_AICUP_training_2025-11-10_08-19-13/logs/
#   inflating: /content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_f1259_00000_0_exp=exp_AICUP_training_2025-11-10_08-19-13/logs/events.out.tfevents.1762762768.4b82d927c11d.9308.0
#   inflating: /content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_f1259_00000_0_exp=exp_AICUP_training_2025-11-10_08-19-13/logs/events.out.tfevents.1762766524.4b82d927c11d.9308.1

# %% [markdown]
# # 推論設定

# %%
import os

workspace_dir = '/content/CardiacSegV2'
model_name = 'unet3d' #unet3d
data_name = 'chgh'
#sub_data_dir_name = 'dataset_3'
exp_name = 'AICUP_training'
data_dict_file_name = 'AICUP_training.json'

# set exp dir
root_exp_dir = os.path.join(workspace_dir,'exps','exps',model_name,data_name,'tune_results')

# set data dir
root_data_dir = os.path.join(workspace_dir,'dataset',data_name)
#data_dir = os.path.join(root_data_dir, sub_data_dir_name)
data_dir = os.path.join(root_data_dir)
# data dict json path
data_dicts_json = os.path.join(workspace_dir, 'exps', 'data_dicts', data_name, data_dict_file_name)

# set model, log, eval dir
model_dir = os.path.join('./', 'models')
log_dir = os.path.join('./', 'logs')
eval_dir = os.path.join('./', 'evals')
os.makedirs(model_dir, exist_ok=True)
os.makedirs(log_dir, exist_ok=True)
os.makedirs(eval_dir, exist_ok=True)


# model path
best_checkpoint = os.path.join(model_dir, 'best_model.pth')
final_checkpoint = os.path.join(model_dir, 'final_model.pth')

# mkdir root exp dir
os.makedirs(root_exp_dir, exist_ok=True)

# %%
import sys
workspace_dir = '/content/CardiacSegV2'
sys.path.append(workspace_dir)

import os
#from expers.infer_utils import get_tune_model_dir, get_data_path, get_pred_path

model_name = "unet3d" #unet3d
data_name = 'chgh'
exp_name = 'AICUP_training'

root_exp_dir = os.path.join(workspace_dir,'exps','exps',model_name,data_name,'tune_results')
model_dir = get_tune_model_dir(root_exp_dir, exp_name)
best_checkpoint = os.path.join(model_dir, 'best_model.pth')
infer_dir = os.path.join('/content/drive/MyDrive/myo_pred',"chgh","infer")
#
# Out:
# Loading results from /content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training...
#
# Best trial f1259_00000:
# config: {'exp': {'exp': 'AICUP_training'}}
# tt_dice: nan
# best log dir: /content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_f1259_00000_0_exp=exp_AICUP_training_2025-11-10_08-19-13

# %% [markdown]
# # 執行推論

# %%
import numpy as np
from scipy.ndimage import label

# %%
import numpy as np
from scipy.ndimage import label

def largest_cc(mask, cls):
    # mask: 3D 或 2D，內容是 0,1,2,3...
    binary = (mask == cls)
    labeled, num = label(binary)
    if num == 0:
        return binary  # 沒有這個 class，就原樣回傳空
    sizes = np.bincount(labeled.ravel())
    sizes[0] = 0  # 0 是背景
    max_label = sizes.argmax()
    return (labeled == max_label)

def postprocess(pred):
    new = np.zeros_like(pred)
    for c in [1, 2, 3]:  # 依你任務調整
        new[largest_cc(pred, c)] = c
    return new

# %%
for img_pth in pred_img:
  # !python /content/CardiacSegV2/expers/infer.py \
  --model_name={model_name} \
  --data_name={data_name} \
  --data_dir={data_dir} \
  --model_dir={model_dir} \
  --infer_dir={infer_dir} \
  --checkpoint={best_checkpoint} \
  --img_pth={img_pth} \
  --out_channels=4 \
  --patch_size=2 \
  --feature_size=48 \
  --drop_rate=0.1 \
  --depths 3 3 9 3 \
  --kernel_size 7 \
  --exp_rate 4 \
  --norm_name='layer' \
  --a_min=-42 \
  --a_max=423 \
  --space_x=0.7 \
  --space_y=0.7 \
  --space_z=1.0 \
  --roi_x=128 \
  --roi_y=128 \
  --roi_z=128 \
  --infer_post_process
# Out:
# 2025-11-10 11:29:41.091427: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762774181.112978   35782 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762774181.118843   35782 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-10 11:29:41.137965: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# cuda is available
# model: unet3d
# => loaded checkpoint '/content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_f1259_00000_0_exp=exp_AICUP_training_2025-11-10_08-19-13/models/best_model.pth'
# infer data: {'image': '/content/drive/MyDrive/myo_pred/chgh/image/patient0051.nii.gz'}
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:321: FutureWarning: monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
#   warn_deprecated(argname, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:221: FutureWarning: monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
#   warn_deprecated(argname, msg, warning_category)
# infer time: 0.8144681453704834 sec
# use post process infer
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.array.AddChannel'>: Class `AddChannel` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirst instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# 2025-11-10 11:29:54,651 INFO image_writer.py:197 - writing: /content/drive/MyDrive/myo_pred/chgh/infer/patient0051.nii.gz
# 2025-11-10 11:30:07.621745: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762774207.641556   35937 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762774207.647435   35937 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-10 11:30:07.666544: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# cuda is available
# model: unet3d
# => loaded checkpoint '/content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_f1259_00000_0_exp=exp_AICUP_training_2025-11-10_08-19-13/models/best_model.pth'
# infer data: {'image': '/content/drive/MyDrive/myo_pred/chgh/image/patient0052.nii.gz'}
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:321: FutureWarning: monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
#   warn_deprecated(argname, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:221: FutureWarning: monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
#   warn_deprecated(argname, msg, warning_category)
# infer time: 0.8214311599731445 sec
# use post process infer
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.array.AddChannel'>: Class `AddChannel` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirst instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# 2025-11-10 11:30:19,585 INFO image_writer.py:197 - writing: /content/drive/MyDrive/myo_pred/chgh/infer/patient0052.nii.gz
# 2025-11-10 11:30:32.410221: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762774232.430383   36076 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762774232.436617   36076 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-10 11:30:32.456210: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# cuda is available
# model: unet3d
# => loaded checkpoint '/content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_f1259_00000_0_exp=exp_AICUP_training_2025-11-10_08-19-13/models/best_model.pth'
# infer data: {'image': '/content/drive/MyDrive/myo_pred/chgh/image/patient0053.nii.gz'}
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:321: FutureWarning: monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
#   warn_deprecated(argname, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:221: FutureWarning: monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
#   warn_deprecated(argname, msg, warning_category)
# infer time: 0.8191659450531006 sec
# use post process infer
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.array.AddChannel'>: Class `AddChannel` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirst instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# 2025-11-10 11:30:44,457 INFO image_writer.py:197 - writing: /content/drive/MyDrive/myo_pred/chgh/infer/patient0053.nii.gz
# 2025-11-10 11:30:57.226219: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762774257.245798   36221 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762774257.251690   36221 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-10 11:30:57.271256: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# cuda is available
# model: unet3d
# => loaded checkpoint '/content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_f1259_00000_0_exp=exp_AICUP_training_2025-11-10_08-19-13/models/best_model.pth'
# infer data: {'image': '/content/drive/MyDrive/myo_pred/chgh/image/patient0054.nii.gz'}
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:321: FutureWarning: monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
#   warn_deprecated(argname, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:221: FutureWarning: monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
#   warn_deprecated(argname, msg, warning_category)
# infer time: 0.8252406120300293 sec
# use post process infer
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.array.AddChannel'>: Class `AddChannel` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirst instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# 2025-11-10 11:31:11,477 INFO image_writer.py:197 - writing: /content/drive/MyDrive/myo_pred/chgh/infer/patient0054.nii.gz
# 2025-11-10 11:31:24.569841: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762774284.590246   36374 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762774284.596312   36374 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-10 11:31:24.616272: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# cuda is available
# model: unet3d
# => loaded checkpoint '/content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_f1259_00000_0_exp=exp_AICUP_training_2025-11-10_08-19-13/models/best_model.pth'
# infer data: {'image': '/content/drive/MyDrive/myo_pred/chgh/image/patient0055.nii.gz'}
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:321: FutureWarning: monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
#   warn_deprecated(argname, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:221: FutureWarning: monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
#   warn_deprecated(argname, msg, warning_category)
# infer time: 0.8455605506896973 sec
# use post process infer
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.array.AddChannel'>: Class `AddChannel` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirst instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# 2025-11-10 11:31:37,285 INFO image_writer.py:197 - writing: /content/drive/MyDrive/myo_pred/chgh/infer/patient0055.nii.gz
# 2025-11-10 11:31:49.948666: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762774309.968866   36523 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762774309.974877   36523 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-10 11:31:49.994205: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# cuda is available
# model: unet3d
# => loaded checkpoint '/content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_f1259_00000_0_exp=exp_AICUP_training_2025-11-10_08-19-13/models/best_model.pth'
# infer data: {'image': '/content/drive/MyDrive/myo_pred/chgh/image/patient0056.nii.gz'}
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:321: FutureWarning: monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
#   warn_deprecated(argname, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:221: FutureWarning: monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
#   warn_deprecated(argname, msg, warning_category)
# infer time: 0.5108046531677246 sec
# use post process infer
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.array.AddChannel'>: Class `AddChannel` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirst instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# 2025-11-10 11:31:59,747 INFO image_writer.py:197 - writing: /content/drive/MyDrive/myo_pred/chgh/infer/patient0056.nii.gz
# 2025-11-10 11:32:11.912446: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762774331.932330   36656 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762774331.938274   36656 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-10 11:32:11.957378: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# cuda is available
# model: unet3d
# => loaded checkpoint '/content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_f1259_00000_0_exp=exp_AICUP_training_2025-11-10_08-19-13/models/best_model.pth'
# infer data: {'image': '/content/drive/MyDrive/myo_pred/chgh/image/patient0058.nii.gz'}
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:321: FutureWarning: monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
#   warn_deprecated(argname, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:221: FutureWarning: monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
#   warn_deprecated(argname, msg, warning_category)
# infer time: 0.8395533561706543 sec
# use post process infer
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.array.AddChannel'>: Class `AddChannel` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirst instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# 2025-11-10 11:32:23,582 INFO image_writer.py:197 - writing: /content/drive/MyDrive/myo_pred/chgh/infer/patient0058.nii.gz
# 2025-11-10 11:32:36.274502: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762774356.294447   36795 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762774356.300560   36795 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-10 11:32:36.320146: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# cuda is available
# model: unet3d
# => loaded checkpoint '/content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_f1259_00000_0_exp=exp_AICUP_training_2025-11-10_08-19-13/models/best_model.pth'
# infer data: {'image': '/content/drive/MyDrive/myo_pred/chgh/image/patient0057.nii.gz'}
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:321: FutureWarning: monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
#   warn_deprecated(argname, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:221: FutureWarning: monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
#   warn_deprecated(argname, msg, warning_category)
# infer time: 0.8455793857574463 sec
# use post process infer
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.array.AddChannel'>: Class `AddChannel` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirst instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# 2025-11-10 11:32:49,942 INFO image_writer.py:197 - writing: /content/drive/MyDrive/myo_pred/chgh/infer/patient0057.nii.gz
# 2025-11-10 11:33:02.976227: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762774382.996347   36940 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762774383.002439   36940 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-10 11:33:03.022030: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# cuda is available
# model: unet3d
# => loaded checkpoint '/content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_f1259_00000_0_exp=exp_AICUP_training_2025-11-10_08-19-13/models/best_model.pth'
# infer data: {'image': '/content/drive/MyDrive/myo_pred/chgh/image/patient0059.nii.gz'}
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:321: FutureWarning: monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
#   warn_deprecated(argname, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:221: FutureWarning: monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
#   warn_deprecated(argname, msg, warning_category)
# infer time: 0.823833703994751 sec
# use post process infer
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.array.AddChannel'>: Class `AddChannel` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirst instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# 2025-11-10 11:33:13,864 INFO image_writer.py:197 - writing: /content/drive/MyDrive/myo_pred/chgh/infer/patient0059.nii.gz
# 2025-11-10 11:33:26.466165: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762774406.486348   37083 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762774406.492321   37083 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-10 11:33:26.511994: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# cuda is available
# model: unet3d
# => loaded checkpoint '/content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_f1259_00000_0_exp=exp_AICUP_training_2025-11-10_08-19-13/models/best_model.pth'
# infer data: {'image': '/content/drive/MyDrive/myo_pred/chgh/image/patient0060.nii.gz'}
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:321: FutureWarning: monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
#   warn_deprecated(argname, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:221: FutureWarning: monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
#   warn_deprecated(argname, msg, warning_category)
# infer time: 0.8516883850097656 sec
# use post process infer
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.array.AddChannel'>: Class `AddChannel` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirst instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# 2025-11-10 11:33:40,748 INFO image_writer.py:197 - writing: /content/drive/MyDrive/myo_pred/chgh/infer/patient0060.nii.gz
# 2025-11-10 11:33:54.058821: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762774434.078599   37234 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762774434.084448   37234 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-10 11:33:54.103729: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# cuda is available
# model: unet3d
# => loaded checkpoint '/content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_f1259_00000_0_exp=exp_AICUP_training_2025-11-10_08-19-13/models/best_model.pth'
# infer data: {'image': '/content/drive/MyDrive/myo_pred/chgh/image/patient0061.nii.gz'}
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:321: FutureWarning: monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
#   warn_deprecated(argname, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:221: FutureWarning: monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
#   warn_deprecated(argname, msg, warning_category)
# infer time: 0.820692777633667 sec
# use post process infer
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.array.AddChannel'>: Class `AddChannel` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirst instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# 2025-11-10 11:34:05,051 INFO image_writer.py:197 - writing: /content/drive/MyDrive/myo_pred/chgh/infer/patient0061.nii.gz
# 2025-11-10 11:34:17.588852: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762774457.609008   37377 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762774457.614840   37377 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-10 11:34:17.633789: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# cuda is available
# model: unet3d
# => loaded checkpoint '/content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_f1259_00000_0_exp=exp_AICUP_training_2025-11-10_08-19-13/models/best_model.pth'
# infer data: {'image': '/content/drive/MyDrive/myo_pred/chgh/image/patient0062.nii.gz'}
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:321: FutureWarning: monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
#   warn_deprecated(argname, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:221: FutureWarning: monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
#   warn_deprecated(argname, msg, warning_category)
# infer time: 0.8274495601654053 sec
# use post process infer
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.array.AddChannel'>: Class `AddChannel` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirst instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# 2025-11-10 11:34:29,676 INFO image_writer.py:197 - writing: /content/drive/MyDrive/myo_pred/chgh/infer/patient0062.nii.gz
# 2025-11-10 11:34:42.035098: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762774482.055001   37520 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762774482.061179   37520 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-10 11:34:42.080239: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# cuda is available
# model: unet3d
# => loaded checkpoint '/content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_f1259_00000_0_exp=exp_AICUP_training_2025-11-10_08-19-13/models/best_model.pth'
# infer data: {'image': '/content/drive/MyDrive/myo_pred/chgh/image/patient0063.nii.gz'}
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:321: FutureWarning: monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
#   warn_deprecated(argname, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:221: FutureWarning: monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
#   warn_deprecated(argname, msg, warning_category)
# infer time: 0.8180205821990967 sec
# use post process infer
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.array.AddChannel'>: Class `AddChannel` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirst instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# 2025-11-10 11:34:55,164 INFO image_writer.py:197 - writing: /content/drive/MyDrive/myo_pred/chgh/infer/patient0063.nii.gz
# 2025-11-10 11:35:07.634256: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762774507.653787   37671 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762774507.659629   37671 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-10 11:35:07.678724: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# cuda is available
# model: unet3d
# => loaded checkpoint '/content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_f1259_00000_0_exp=exp_AICUP_training_2025-11-10_08-19-13/models/best_model.pth'
# infer data: {'image': '/content/drive/MyDrive/myo_pred/chgh/image/patient0065.nii.gz'}
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:321: FutureWarning: monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
#   warn_deprecated(argname, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:221: FutureWarning: monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
#   warn_deprecated(argname, msg, warning_category)
# infer time: 0.8247301578521729 sec
# use post process infer
# ...
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# cuda is available
# model: unet3d
# => loaded checkpoint '/content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_f1259_00000_0_exp=exp_AICUP_training_2025-11-10_08-19-13/models/best_model.pth'
# infer data: {'image': '/content/drive/MyDrive/myo_pred/chgh/image/patient0096.nii.gz'}
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:321: FutureWarning: monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
#   warn_deprecated(argname, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:221: FutureWarning: monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
#   warn_deprecated(argname, msg, warning_category)
# infer time: 0.8224506378173828 sec
# use post process infer
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.array.AddChannel'>: Class `AddChannel` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirst instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# 2025-11-10 11:48:44,718 INFO image_writer.py:197 - writing: /content/drive/MyDrive/myo_pred/chgh/infer/patient0096.nii.gz
# 2025-11-10 11:48:57.224956: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762775337.249857   42448 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762775337.256638   42448 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-10 11:48:57.276520: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# cuda is available
# model: unet3d
# => loaded checkpoint '/content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_f1259_00000_0_exp=exp_AICUP_training_2025-11-10_08-19-13/models/best_model.pth'
# infer data: {'image': '/content/drive/MyDrive/myo_pred/chgh/image/patient0097.nii.gz'}
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:321: FutureWarning: monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
#   warn_deprecated(argname, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:221: FutureWarning: monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
#   warn_deprecated(argname, msg, warning_category)
# infer time: 0.8255598545074463 sec
# use post process infer
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.array.AddChannel'>: Class `AddChannel` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirst instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# 2025-11-10 11:49:08,974 INFO image_writer.py:197 - writing: /content/drive/MyDrive/myo_pred/chgh/infer/patient0097.nii.gz
# 2025-11-10 11:49:21.282794: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762775361.304731   42583 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762775361.310869   42583 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-10 11:49:21.330404: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# cuda is available
# model: unet3d
# => loaded checkpoint '/content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_f1259_00000_0_exp=exp_AICUP_training_2025-11-10_08-19-13/models/best_model.pth'
# infer data: {'image': '/content/drive/MyDrive/myo_pred/chgh/image/patient0098.nii.gz'}
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:321: FutureWarning: monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
#   warn_deprecated(argname, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:221: FutureWarning: monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
#   warn_deprecated(argname, msg, warning_category)
# infer time: 1.2816212177276611 sec
# use post process infer
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.array.AddChannel'>: Class `AddChannel` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirst instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# 2025-11-10 11:49:34,837 INFO image_writer.py:197 - writing: /content/drive/MyDrive/myo_pred/chgh/infer/patient0098.nii.gz
# 2025-11-10 11:49:47.147558: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762775387.167133   42732 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762775387.173074   42732 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-10 11:49:47.192936: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# cuda is available
# model: unet3d
# => loaded checkpoint '/content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_f1259_00000_0_exp=exp_AICUP_training_2025-11-10_08-19-13/models/best_model.pth'
# infer data: {'image': '/content/drive/MyDrive/myo_pred/chgh/image/patient0099.nii.gz'}
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:321: FutureWarning: monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
#   warn_deprecated(argname, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:221: FutureWarning: monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
#   warn_deprecated(argname, msg, warning_category)
# infer time: 0.8471255302429199 sec
# use post process infer
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.array.AddChannel'>: Class `AddChannel` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirst instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# 2025-11-10 11:50:00,881 INFO image_writer.py:197 - writing: /content/drive/MyDrive/myo_pred/chgh/infer/patient0099.nii.gz
# 2025-11-10 11:50:13.243706: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762775413.263454   42881 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762775413.269774   42881 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-10 11:50:13.289018: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.11/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# cuda is available
# model: unet3d
# => loaded checkpoint '/content/CardiacSegV2/exps/exps/unet3d/chgh/tune_results/AICUP_training/main_f1259_00000_0_exp=exp_AICUP_training_2025-11-10_08-19-13/models/best_model.pth'
# infer data: {'image': '/content/drive/MyDrive/myo_pred/chgh/image/patient0100.nii.gz'}
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:321: FutureWarning: monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
#   warn_deprecated(argname, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.dictionary.AddChanneld'>: Class `AddChanneld` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirstd instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:221: FutureWarning: monai.transforms.utility.dictionary EnsureChannelFirstd.__init__:meta_keys: Argument `meta_keys` has been deprecated since version 0.9. not needed if image is type `MetaTensor`.
#   warn_deprecated(argname, msg, warning_category)
# infer time: 0.8365004062652588 sec
# use post process infer
# /usr/local/lib/python3.11/dist-packages/monai/utils/deprecate_utils.py:111: FutureWarning: <class 'monai.transforms.utility.array.AddChannel'>: Class `AddChannel` has been deprecated since version 0.8. It will be removed in version 1.3. please use MetaTensor data type and monai.transforms.EnsureChannelFirst instead with `channel_dim='no_channel'`.
#   warn_deprecated(obj, msg, warning_category)
# 2025-11-10 11:50:25,419 INFO image_writer.py:197 - writing: /content/drive/MyDrive/myo_pred/chgh/infer/patient0100.nii.gz

# %% [markdown]
# # 從infer資料夾下載成壓縮檔，下載後就可以直接提交
# - 記得先去執行
# ```
# from google.colab import drive
# drive.mount('/content/drive')
# ```

# %%
import shutil
import os
from google.colab import files

os.chdir("/content/drive/MyDrive/myo_pred/chgh/infer")

zip_path = "/content/contest1"
shutil.make_archive(zip_path, 'zip', root_dir='.', base_dir='.')

files.download(zip_path + ".zip")
